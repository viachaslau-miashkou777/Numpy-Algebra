# %% [markdown]
# <h1 style="margin-bottom: 25px;font-size:3.5rem;color:#4c76ce;text-align:center;">
#     Getting Started with Pandas</h1>
#
# <h2 style="margin-bottom: 25px;font-size:2.5rem;text-align:center;">
#     Part III - Pandas: Data Aggregation</h2>
#
# <img src="https://raw.githubusercontent.com/lajmcourses/Images/master/pandas.png"
#      style="position:absolute;top:5px;left:25px;height:150px;width:auto;margin-bottom:25px;">

# %%
import numpy as np
import pandas as pd

# Set decimal number display precision (Pandas objects)
pd.options.display.precision = 2
pd.options.display.float_format = '{:.2f}'.format

# %%
# Data

df_data = pd.read_csv("data/titanic.csv")
df_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male 22.00      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female 38.00      1
# 2                             Heikkinen, Miss. Laina  female 26.00      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.00      1
# 4                           Allen, Mr. William Henry    male 35.00      0
#
#    Parch            Ticket  Fare Cabin Embarked
# 0      0         A/5 21171  7.25   NaN        S
# 1      0          PC 17599 71.28   C85        C
# 2      0  STON/O2. 3101282  7.92   NaN        S
# 3      0            113803 53.10  C123        S
# 4      0            373450  8.05   NaN        S

# %%
df_data.describe()
# Out:
#        PassengerId  Survived  Pclass    Age  SibSp  Parch   Fare
# count       891.00    891.00  891.00 714.00 891.00 891.00 891.00
# mean        446.00      0.38    2.31  29.70   0.52   0.38  32.20
# std         257.35      0.49    0.84  14.53   1.10   0.81  49.69
# min           1.00      0.00    1.00   0.42   0.00   0.00   0.00
# 25%         223.50      0.00    2.00  20.12   0.00   0.00   7.91
# 50%         446.00      0.00    3.00  28.00   0.00   0.00  14.45
# 75%         668.50      1.00    3.00  38.00   1.00   0.00  31.00
# max         891.00      1.00    3.00  80.00   8.00   6.00 512.33

# %%
df_data.describe(include="object")
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df_data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ## 1. Data Grouping

# %%
# Group by Class
group_by_class = df_data.groupby("Pclass")

# Display Groups
for cls_name, cls_df in group_by_class:
    ## Group name
    print(f"Group: {cls_name}")
    display(cls_df.head())
# Out:
# Group: 1
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 11           12         1       1
# 23           24         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female 38.00      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.00      1
# 6                             McCarthy, Mr. Timothy J    male 54.00      0
# 11                           Bonnell, Miss. Elizabeth  female 58.00      0
# 23                       Sloper, Mr. William Thompson    male 28.00      0
#
#     Parch    Ticket  Fare Cabin Embarked
# 1       0  PC 17599 71.28   C85        C
# 3       0    113803 53.10  C123        S
# 6       0     17463 51.86   E46        S
# 11      0    113783 26.55  C103        S
# 23      0    113788 35.50    A6        S
# Group: 2
#     PassengerId  Survived  Pclass                                 Name  \
# 9            10         1       2  Nasser, Mrs. Nicholas (Adele Achem)
# 15           16         1       2     Hewlett, Mrs. (Mary D Kingcome)
# 17           18         1       2         Williams, Mr. Charles Eugene
# 20           21         0       2                 Fynney, Mr. Joseph J
# 21           22         1       2                Beesley, Mr. Lawrence
#
#        Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 9   female 14.00      1      0  237736 30.07   NaN        C
# 15  female 55.00      0      0  248706 16.00   NaN        S
# 17    male   NaN      0      0  244373 13.00   NaN        S
# 20    male 35.00      0      0  239865 26.00   NaN        S
# 21    male 34.00      0      0  248698 13.00   D56        S
# Group: 3
#    PassengerId  Survived  Pclass                            Name     Sex  \
# 0            1         0       3         Braund, Mr. Owen Harris    male
# 2            3         1       3          Heikkinen, Miss. Laina  female
# 4            5         0       3        Allen, Mr. William Henry    male
# 5            6         0       3                Moran, Mr. James    male
# 7            8         0       3  Palsson, Master. Gosta Leonard    male
#
#     Age  SibSp  Parch            Ticket  Fare Cabin Embarked
# 0 22.00      1      0         A/5 21171  7.25   NaN        S
# 2 26.00      0      0  STON/O2. 3101282  7.92   NaN        S
# 4 35.00      0      0            373450  8.05   NaN        S
# 5   NaN      0      0            330877  8.46   NaN        Q
# 7  2.00      3      1            349909 21.07   NaN        S

# %% [markdown]
# ## 2. Group Aggregation Functions

# %%
# Group Mean:
group_by_class[["Survived", "Age", "Fare"]].mean()
# Out:
#         Survived   Age  Fare
# Pclass
# 1           0.63 38.23 84.15
# 2           0.47 29.88 20.66
# 3           0.24 25.14 13.68

# %%
# Group Count: Passengers by Class
display(group_by_class[["PassengerId"]].count())
# Out:
#         PassengerId
# Pclass
# 1               216
# 2               184
# 3               491

# %%
# Group Sum: Survived Passengers by Class
display(group_by_class[["Survived"]].sum())

# We can also apply multiple aggregation functions
group_by_class[["Survived"]].agg(["sum", "count"])
# Out:
#         Survived
# Pclass
# 1            136
# 2             87
# 3            119
#        Survived
#             sum count
# Pclass
# 1           136   216
# 2            87   184
# 3           119   491

# %%
# Multiple Aggregation Functions on a Single Column 
group_by_class[["Age"]].agg(['mean', 'std', 'median'])
# Out:
#          Age
#         mean   std median
# Pclass
# 1      38.23 14.80  37.00
# 2      29.88 14.00  29.00
# 3      25.14 12.50  24.00

# %%
# Multiple Aggregation Function on Multiple Columns
group_by_class.agg(
    mean_age = ("Age", lambda x: x.mean()),
    std_age = ("Age", "std"),
    
    mean_fare = ("Fare", lambda x: x.mean()),
    std_fare = ("Fare", "std")
    )
# Out:
#         mean_age  std_age  mean_fare  std_fare
# Pclass
# 1          38.23    14.80      84.15     78.38
# 2          29.88    14.00      20.66     13.42
# 3          25.14    12.50      13.68     11.78

# %% [markdown]
# ## 3.Grouping by Multiple Variables

# %%
group_by_class_by_age = df_data.groupby(["Pclass", "Sex"])

group_by_class_by_age[["Age", "Fare"]].mean()
# Out:
#                 Age   Fare
# Pclass Sex
# 1      female 34.61 106.13
#        male   41.28  67.23
# 2      female 28.72  21.97
#        male   30.74  19.74
# 3      female 21.75  16.12
#        male   26.51  12.66

# %% [markdown]
# ## User Defined Aggregation Functions

# %%
# Example 1

group_by_class.apply(lambda df_data: pd.Series(df_data.shape, index=["nrow", "ncol"]))
# Out:
#         nrow  ncol
# Pclass
# 1        216    12
# 2        184    12
# 3        491    12
